# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 774

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | neiafu
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | pangnirtung
# Processing Record 5 of Set 1 | ambilobe
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | biggar
# Processing Record 9 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 1 | half moon bay
# Processing Record 11 of Set 1 | naze
# Processing Record 12 of Set 1 | ilulissat
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | zdunska wola
# Processing Record 15 of Set 1 | ugoofaaru
# Processing Record 16 of Set 1 | joshimath
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | codrington
# Processing Record 19 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 20 of Set 1 | vardo
# Processing Record 21 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 1 | lorengau
# Processing Record 23 of Set 1 | chara
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | sinnamary
# Processing Record 26 of Set 1 | groa
# Processing Record 27 of Set 1 | gritsovskiy
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | isangel
# Processing Record 30 of Set 1 | fez
# Processing Record 31 of Set 1 | deputatskiy
# Processing Record 32 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | edd
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | alofi
# Processing Record 39 of Set 1 | ostrovnoy
# Processing Record 40 of Set 1 | nanortalik
# Processing Record 41 of Set 1 | zapolyarnyy
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | fomboni
# Processing Record 44 of Set 1 | koygorodok
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | hasaki
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | rajnagar
# Processing Record 2 of Set 2 | bolonchen
# City not found. Skipping...
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | udachnyy
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 2 | mezen
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | acapulco
# Processing Record 12 of Set 2 | suhbaatar
# Processing Record 13 of Set 2 | aksarka
# Processing Record 14 of Set 2 | vostok
# Processing Record 15 of Set 2 | iqaluit
# Processing Record 16 of Set 2 | douglas
# Processing Record 17 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | roma
# Processing Record 21 of Set 2 | adeje
# Processing Record 22 of Set 2 | rosarito
# Processing Record 23 of Set 2 | tura
# Processing Record 24 of Set 2 | aden
# Processing Record 25 of Set 2 | linqing
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | saint pete beach
# Processing Record 28 of Set 2 | olafsvik
# Processing Record 29 of Set 2 | matara
# Processing Record 30 of Set 2 | batemans bay
# Processing Record 31 of Set 2 | soc trang
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | ajalpan
# Processing Record 35 of Set 2 | aksu
# Processing Record 36 of Set 2 | miranda
# Processing Record 37 of Set 2 | tilichiki
# Processing Record 38 of Set 2 | okhotsk
# Processing Record 39 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | tazovskiy
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 2 | nouadhibou
# Processing Record 45 of Set 2 | yangcun
# Processing Record 46 of Set 2 | albuquerque
# Processing Record 47 of Set 2 | ribeira grande
# Processing Record 48 of Set 2 | nicoya
# Processing Record 49 of Set 2 | limaong
# Processing Record 50 of Set 2 | aktau
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | anadyr
# Processing Record 3 of Set 3 | upernavik
# Processing Record 4 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 3 | zhuozhou
# City not found. Skipping...
# Processing Record 6 of Set 3 | shache
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | awjilah
# Processing Record 9 of Set 3 | semirom
# Processing Record 10 of Set 3 | ducheng
# Processing Record 11 of Set 3 | morondava
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | khandyga
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | richards bay
# Processing Record 16 of Set 3 | nuuk
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | mehamn
# Processing Record 19 of Set 3 | fairbanks
# Processing Record 20 of Set 3 | bluff
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | los llanos de aridane
# Processing Record 23 of Set 3 | faya
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | bambous virieux
# Processing Record 26 of Set 3 | trairi
# Processing Record 27 of Set 3 | praia da vitoria
# Processing Record 28 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | leningradskiy
# Processing Record 31 of Set 3 | wattegama
# Processing Record 32 of Set 3 | mazulskiy
# City not found. Skipping...
# Processing Record 33 of Set 3 | cidreira
# Processing Record 34 of Set 3 | katsuura
# Processing Record 35 of Set 3 | tasiilaq
# Processing Record 36 of Set 3 | carnarvon
# Processing Record 37 of Set 3 | tuatapere
# Processing Record 38 of Set 3 | souillac
# Processing Record 39 of Set 3 | severo-yeniseyskiy
# Processing Record 40 of Set 3 | kautokeino
# Processing Record 41 of Set 3 | yanji
# Processing Record 42 of Set 3 | griffith
# Processing Record 43 of Set 3 | shiraoi
# Processing Record 44 of Set 3 | eureka
# Processing Record 45 of Set 3 | salvador
# Processing Record 46 of Set 3 | kalabo
# Processing Record 47 of Set 3 | claremorris
# Processing Record 48 of Set 3 | maragogi
# Processing Record 49 of Set 3 | bilibino
# Processing Record 50 of Set 3 | pousat
# City not found. Skipping...
# Processing Record 1 of Set 4 | matagami
# Processing Record 2 of Set 4 | portree
# Processing Record 3 of Set 4 | nome
# Processing Record 4 of Set 4 | dingle
# Processing Record 5 of Set 4 | aklavik
# Processing Record 6 of Set 4 | sao filipe
# Processing Record 7 of Set 4 | provideniya
# Processing Record 8 of Set 4 | new norfolk
# Processing Record 9 of Set 4 | ilabaya
# Processing Record 10 of Set 4 | jamestown
# Processing Record 11 of Set 4 | georgetown
# Processing Record 12 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | taoudenni
# Processing Record 15 of Set 4 | hofn
# Processing Record 16 of Set 4 | makat
# Processing Record 17 of Set 4 | bubaque
# Processing Record 18 of Set 4 | tallahassee
# Processing Record 19 of Set 4 | tanabe
# Processing Record 20 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 4 | geraldton
# Processing Record 22 of Set 4 | roald
# Processing Record 23 of Set 4 | tempio pausania
# Processing Record 24 of Set 4 | biltine
# Processing Record 25 of Set 4 | olinda
# Processing Record 26 of Set 4 | qaqortoq
# Processing Record 27 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 4 | warrnambool
# Processing Record 29 of Set 4 | east london
# Processing Record 30 of Set 4 | lebu
# Processing Record 31 of Set 4 | aykhal
# Processing Record 32 of Set 4 | poum
# Processing Record 33 of Set 4 | cherskiy
# Processing Record 34 of Set 4 | bengkulu
# Processing Record 35 of Set 4 | gornopravdinsk
# Processing Record 36 of Set 4 | huarmey
# Processing Record 37 of Set 4 | daru
# Processing Record 38 of Set 4 | otane
# Processing Record 39 of Set 4 | saint-philippe
# Processing Record 40 of Set 4 | pevek
# Processing Record 41 of Set 4 | san carlos
# Processing Record 42 of Set 4 | kloulklubed
# Processing Record 43 of Set 4 | oranjemund
# Processing Record 44 of Set 4 | marapanim
# Processing Record 45 of Set 4 | saundatti yellamma
# City not found. Skipping...
# Processing Record 46 of Set 4 | mareeba
# Processing Record 47 of Set 4 | ferrol
# Processing Record 48 of Set 4 | tessalit
# Processing Record 49 of Set 4 | broome
# Processing Record 50 of Set 4 | ponta do sol
# Processing Record 1 of Set 5 | sao gabriel da cachoeira
# Processing Record 2 of Set 5 | oktyabrskiy
# Processing Record 3 of Set 5 | kavaratti
# Processing Record 4 of Set 5 | faanui
# Processing Record 5 of Set 5 | loksa
# Processing Record 6 of Set 5 | moose factory
# Processing Record 7 of Set 5 | warri
# Processing Record 8 of Set 5 | barsovo
# Processing Record 9 of Set 5 | nchelenge
# Processing Record 10 of Set 5 | majene
# Processing Record 11 of Set 5 | hongjiang
# Processing Record 12 of Set 5 | krizevci
# Processing Record 13 of Set 5 | acarau
# Processing Record 14 of Set 5 | padang
# Processing Record 15 of Set 5 | guerrero negro
# Processing Record 16 of Set 5 | nemuro
# Processing Record 17 of Set 5 | sisimiut
# Processing Record 18 of Set 5 | rundu
# Processing Record 19 of Set 5 | walvis bay
# Processing Record 20 of Set 5 | lobito
# Processing Record 21 of Set 5 | paita
# Processing Record 22 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 5 | skibbereen
# Processing Record 24 of Set 5 | baruun-urt
# Processing Record 25 of Set 5 | margate
# Processing Record 26 of Set 5 | ancud
# Processing Record 27 of Set 5 | polyarnyy
# Processing Record 28 of Set 5 | staryy nadym
# Processing Record 29 of Set 5 | tautira
# Processing Record 30 of Set 5 | novyy svit
# Processing Record 31 of Set 5 | emerald
# Processing Record 32 of Set 5 | puerto escondido
# Processing Record 33 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 5 | meulaboh
# Processing Record 35 of Set 5 | pasighat
# Processing Record 36 of Set 5 | rivne
# Processing Record 37 of Set 5 | bud
# Processing Record 38 of Set 5 | viedma
# Processing Record 39 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 5 | olga
# Processing Record 41 of Set 5 | toora-khem
# Processing Record 42 of Set 5 | airai
# Processing Record 43 of Set 5 | saskylakh
# Processing Record 44 of Set 5 | astoria
# Processing Record 45 of Set 5 | lulindi
# Processing Record 46 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 5 | havre-saint-pierre
# Processing Record 48 of Set 5 | razumnoye
# Processing Record 49 of Set 5 | katherine
# Processing Record 50 of Set 5 | khatanga
# Processing Record 1 of Set 6 | klobuck
# Processing Record 2 of Set 6 | chokurdakh
# Processing Record 3 of Set 6 | sur
# Processing Record 4 of Set 6 | thinadhoo
# Processing Record 5 of Set 6 | tari
# Processing Record 6 of Set 6 | westport
# Processing Record 7 of Set 6 | novoagansk
# Processing Record 8 of Set 6 | garowe
# Processing Record 9 of Set 6 | hualmay
# Processing Record 10 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 6 | sumbe
# Processing Record 12 of Set 6 | igboho
# Processing Record 13 of Set 6 | cabo san lucas
# Processing Record 14 of Set 6 | san policarpo
# Processing Record 15 of Set 6 | nieuw amsterdam
# Processing Record 16 of Set 6 | baykit
# Processing Record 17 of Set 6 | port elizabeth
# Processing Record 18 of Set 6 | te anau
# Processing Record 19 of Set 6 | chapais
# Processing Record 20 of Set 6 | bowen
# Processing Record 21 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 6 | alenquer
# Processing Record 23 of Set 6 | vila velha
# Processing Record 24 of Set 6 | port hedland
# Processing Record 25 of Set 6 | sioux lookout
# Processing Record 26 of Set 6 | thompson
# Processing Record 27 of Set 6 | lahaina
# Processing Record 28 of Set 6 | hambantota
# Processing Record 29 of Set 6 | dubbo
# Processing Record 30 of Set 6 | segezha
# Processing Record 31 of Set 6 | kirkwall
# Processing Record 32 of Set 6 | plouzane
# Processing Record 33 of Set 6 | baherden
# Processing Record 34 of Set 6 | yining
# Processing Record 35 of Set 6 | karratha
# Processing Record 36 of Set 6 | tiksi
# Processing Record 37 of Set 6 | kavieng
# Processing Record 38 of Set 6 | thunder bay
# Processing Record 39 of Set 6 | zyryanka
# Processing Record 40 of Set 6 | bredasdorp
# Processing Record 41 of Set 6 | alamos
# Processing Record 42 of Set 6 | vikulovo
# Processing Record 43 of Set 6 | mopipi
# Processing Record 44 of Set 6 | tucurui
# Processing Record 45 of Set 6 | kampene
# Processing Record 46 of Set 6 | galle
# Processing Record 47 of Set 6 | onega
# Processing Record 48 of Set 6 | yulara
# Processing Record 49 of Set 6 | komsomolskiy
# Processing Record 50 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 7 | severo-kurilsk
# Processing Record 2 of Set 7 | buraydah
# Processing Record 3 of Set 7 | priargunsk
# Processing Record 4 of Set 7 | kurchum
# Processing Record 5 of Set 7 | gorom-gorom
# Processing Record 6 of Set 7 | alekseyevsk
# Processing Record 7 of Set 7 | hamilton
# Processing Record 8 of Set 7 | flinders
# Processing Record 9 of Set 7 | groningen
# Processing Record 10 of Set 7 | hwange
# Processing Record 11 of Set 7 | vysokogornyy
# Processing Record 12 of Set 7 | palasa
# Processing Record 13 of Set 7 | jiaojiang
# Processing Record 14 of Set 7 | taitung
# Processing Record 15 of Set 7 | mugumu
# Processing Record 16 of Set 7 | las vegas
# Processing Record 17 of Set 7 | barinas
# Processing Record 18 of Set 7 | dayong
# Processing Record 19 of Set 7 | nyurba
# Processing Record 20 of Set 7 | porbandar
# Processing Record 21 of Set 7 | panacan
# Processing Record 22 of Set 7 | capinzal
# Processing Record 23 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 7 | muros
# Processing Record 25 of Set 7 | viransehir
# Processing Record 26 of Set 7 | saint george
# Processing Record 27 of Set 7 | maniitsoq
# Processing Record 28 of Set 7 | shitanjing
# Processing Record 29 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 31 of Set 7 | plainview
# Processing Record 32 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 7 | itarema
# Processing Record 34 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 7 | socorro
# Processing Record 36 of Set 7 | kon tum
# Processing Record 37 of Set 7 | vestmannaeyjar
# Processing Record 38 of Set 7 | benjamin constant
# Processing Record 39 of Set 7 | berlevag
# Processing Record 40 of Set 7 | krasnoselkup
# Processing Record 41 of Set 7 | neijiang
# Processing Record 42 of Set 7 | yeppoon
# Processing Record 43 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 7 | monticello
# Processing Record 45 of Set 7 | angren
# Processing Record 46 of Set 7 | haines junction
# Processing Record 47 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 7 | dhidhdhoo
# Processing Record 49 of Set 7 | doha
# Processing Record 50 of Set 7 | houston
# Processing Record 1 of Set 8 | tuktoyaktuk
# Processing Record 2 of Set 8 | morris
# Processing Record 3 of Set 8 | norman wells
# Processing Record 4 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 6 of Set 8 | oyama
# Processing Record 7 of Set 8 | sao raimundo das mangabeiras
# Processing Record 8 of Set 8 | clyde river
# Processing Record 9 of Set 8 | castanos
# Processing Record 10 of Set 8 | luanda
# Processing Record 11 of Set 8 | pochutla
# Processing Record 12 of Set 8 | batagay-alyta
# Processing Record 13 of Set 8 | kamaishi
# Processing Record 14 of Set 8 | bathsheba
# Processing Record 15 of Set 8 | carahue
# Processing Record 16 of Set 8 | neiba
# Processing Record 17 of Set 8 | brokopondo
# Processing Record 18 of Set 8 | laguna
# Processing Record 19 of Set 8 | grado
# Processing Record 20 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 8 | turukhansk
# Processing Record 22 of Set 8 | chumikan
# Processing Record 23 of Set 8 | solnechnyy
# Processing Record 24 of Set 8 | cotonou
# Processing Record 25 of Set 8 | port-gentil
# Processing Record 26 of Set 8 | kabare
# Processing Record 27 of Set 8 | gamba
# Processing Record 28 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 29 of Set 8 | bilma
# Processing Record 30 of Set 8 | lokosovo
# Processing Record 31 of Set 8 | brigantine
# Processing Record 32 of Set 8 | tornio
# Processing Record 33 of Set 8 | baghdad
# Processing Record 34 of Set 8 | lata
# Processing Record 35 of Set 8 | dumas
# Processing Record 36 of Set 8 | bandarbeyla
# Processing Record 37 of Set 8 | chauk
# Processing Record 38 of Set 8 | kismayo
# Processing Record 39 of Set 8 | muli
# Processing Record 40 of Set 8 | kaitangata
# Processing Record 41 of Set 8 | puerto del rosario
# Processing Record 42 of Set 8 | saint anthony
# Processing Record 43 of Set 8 | warwick
# Processing Record 44 of Set 8 | fukue
# Processing Record 45 of Set 8 | puerto carreno
# Processing Record 46 of Set 8 | lagoa
# Processing Record 47 of Set 8 | erenhot
# Processing Record 48 of Set 8 | ottumwa
# Processing Record 49 of Set 8 | mount isa
# Processing Record 50 of Set 8 | omsukchan
# Processing Record 1 of Set 9 | college
# Processing Record 2 of Set 9 | wadi musa
# Processing Record 3 of Set 9 | maceio
# Processing Record 4 of Set 9 | port macquarie
# Processing Record 5 of Set 9 | labuhan
# Processing Record 6 of Set 9 | tanshui
# City not found. Skipping...
# Processing Record 7 of Set 9 | kez
# Processing Record 8 of Set 9 | luderitz
# Processing Record 9 of Set 9 | adrar
# Processing Record 10 of Set 9 | la ronge
# Processing Record 11 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 9 | tambopata
# Processing Record 13 of Set 9 | baker city
# Processing Record 14 of Set 9 | santa marta
# Processing Record 15 of Set 9 | chokwe
# Processing Record 16 of Set 9 | ginir
# Processing Record 17 of Set 9 | paamiut
# Processing Record 18 of Set 9 | atbasar
# Processing Record 19 of Set 9 | ayagoz
# Processing Record 20 of Set 9 | prince rupert
# Processing Record 21 of Set 9 | pisco
# Processing Record 22 of Set 9 | saint-francois
# Processing Record 23 of Set 9 | coxim
# Processing Record 24 of Set 9 | nuevitas
# Processing Record 25 of Set 9 | tanete
# Processing Record 26 of Set 9 | kahului
# Processing Record 27 of Set 9 | coihaique
# Processing Record 28 of Set 9 | columbus
# Processing Record 29 of Set 9 | kieta
# Processing Record 30 of Set 9 | chifeng
# Processing Record 31 of Set 9 | valparaiso
# Processing Record 32 of Set 9 | ciudad bolivar
# Processing Record 33 of Set 9 | constitucion
# Processing Record 34 of Set 9 | ponta delgada
# Processing Record 35 of Set 9 | vao
# Processing Record 36 of Set 9 | labytnangi
# Processing Record 37 of Set 9 | mwinilunga
# Processing Record 38 of Set 9 | talara
# Processing Record 39 of Set 9 | kidodi
# Processing Record 40 of Set 9 | saint-georges
# Processing Record 41 of Set 9 | san patricio
# Processing Record 42 of Set 9 | machaneng
# Processing Record 43 of Set 9 | imeni poliny osipenko
# Processing Record 44 of Set 9 | kargil
# Processing Record 45 of Set 9 | auki
# Processing Record 46 of Set 9 | bekhtery
# Processing Record 47 of Set 9 | nibbar
# Processing Record 48 of Set 9 | cap malheureux
# Processing Record 49 of Set 9 | pangai
# Processing Record 50 of Set 9 | aci catena
# Processing Record 1 of Set 10 | kedrovyy
# Processing Record 2 of Set 10 | hisua
# Processing Record 3 of Set 10 | decatur
# Processing Record 4 of Set 10 | ngunguru
# Processing Record 5 of Set 10 | palaiokhora
# City not found. Skipping...
# Processing Record 6 of Set 10 | virginia beach
# Processing Record 7 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 10 | fortuna
# Processing Record 9 of Set 10 | siniscola
# Processing Record 10 of Set 10 | salmo
# Processing Record 11 of Set 10 | ranong
# Processing Record 12 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 13 of Set 10 | mount gambier
# Processing Record 14 of Set 10 | surin
# Processing Record 15 of Set 10 | mumford
# Processing Record 16 of Set 10 | lucea
# Processing Record 17 of Set 10 | tres palos
# Processing Record 18 of Set 10 | hull
# Processing Record 19 of Set 10 | lagdo
# Processing Record 20 of Set 10 | rio gallegos
# Processing Record 21 of Set 10 | ayaviri
# Processing Record 22 of Set 10 | tahta
# Processing Record 23 of Set 10 | loyga
# Processing Record 24 of Set 10 | caravelas
# Processing Record 25 of Set 10 | necochea
# Processing Record 26 of Set 10 | oksovskiy
# Processing Record 27 of Set 10 | isiro
# Processing Record 28 of Set 10 | eucaliptus
# Processing Record 29 of Set 10 | svetlogorsk
# Processing Record 30 of Set 10 | matadi
# Processing Record 31 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 10 | bonavista
# Processing Record 33 of Set 10 | goragorskiy
# Processing Record 34 of Set 10 | roslavl
# Processing Record 35 of Set 10 | manali
# Processing Record 36 of Set 10 | sungaipenuh
# Processing Record 37 of Set 10 | dharmanagar
# Processing Record 38 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 10 | natal
# Processing Record 40 of Set 10 | kuusamo
# Processing Record 41 of Set 10 | kruisfontein
# Processing Record 42 of Set 10 | novaya zaimka
# Processing Record 43 of Set 10 | saurimo
# Processing Record 44 of Set 10 | champerico
# Processing Record 45 of Set 10 | porto belo
# Processing Record 46 of Set 10 | bereda
# Processing Record 47 of Set 10 | vung tau
# Processing Record 48 of Set 10 | washington
# Processing Record 49 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 10 | ibaiti
# Processing Record 1 of Set 11 | savannah bight
# Processing Record 2 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 3 of Set 11 | atar
# Processing Record 4 of Set 11 | glubokoe
# City not found. Skipping...
# Processing Record 5 of Set 11 | lev tolstoy
# Processing Record 6 of Set 11 | ixtapa
# Processing Record 7 of Set 11 | weiser
# Processing Record 8 of Set 11 | north myrtle beach
# Processing Record 9 of Set 11 | khasan
# Processing Record 10 of Set 11 | kudahuvadhoo
# Processing Record 11 of Set 11 | tigil
# Processing Record 12 of Set 11 | coquimbo
# Processing Record 13 of Set 11 | ulladulla
# Processing Record 14 of Set 11 | gobo
# Processing Record 15 of Set 11 | inongo
# Processing Record 16 of Set 11 | saint-pierre
# Processing Record 17 of Set 11 | vila franca do campo
# Processing Record 18 of Set 11 | viloco
# Processing Record 19 of Set 11 | portland
# Processing Record 20 of Set 11 | adwa
# Processing Record 21 of Set 11 | saint-joseph
# Processing Record 22 of Set 11 | goure
# Processing Record 23 of Set 11 | kalispell
# Processing Record 24 of Set 11 | niteroi
# Processing Record 25 of Set 11 | stuttgart
# Processing Record 26 of Set 11 | miracema do tocantins
# Processing Record 27 of Set 11 | clovis
# Processing Record 28 of Set 11 | tambo
# Processing Record 29 of Set 11 | kousseri
# Processing Record 30 of Set 11 | sangar
# Processing Record 31 of Set 11 | kahta
# Processing Record 32 of Set 11 | sal rei
# Processing Record 33 of Set 11 | santiago del estero
# Processing Record 34 of Set 11 | korla
# Processing Record 35 of Set 11 | gilgit
# Processing Record 36 of Set 11 | antsirabe
# Processing Record 37 of Set 11 | khorixas
# Processing Record 38 of Set 11 | loiza
# Processing Record 39 of Set 11 | muzhi
# Processing Record 40 of Set 11 | pierre
# Processing Record 41 of Set 11 | kaseda
# Processing Record 42 of Set 11 | manokwari
# Processing Record 43 of Set 11 | minatitlan
# Processing Record 44 of Set 11 | gao
# Processing Record 45 of Set 11 | yar-sale
# Processing Record 46 of Set 11 | plettenberg bay
# Processing Record 47 of Set 11 | wuwei
# Processing Record 48 of Set 11 | malanje
# Processing Record 49 of Set 11 | lukaya
# Processing Record 50 of Set 11 | rawson
# Processing Record 1 of Set 12 | presidencia roque saenz pena
# Processing Record 2 of Set 12 | hami
# Processing Record 3 of Set 12 | juneau
# Processing Record 4 of Set 12 | jaciara
# Processing Record 5 of Set 12 | klaksvik
# Processing Record 6 of Set 12 | henties bay
# Processing Record 7 of Set 12 | kirksville
# Processing Record 8 of Set 12 | yenagoa
# Processing Record 9 of Set 12 | kandrian
# Processing Record 10 of Set 12 | esmeraldas
# Processing Record 11 of Set 12 | banka
# Processing Record 12 of Set 12 | charlestown
# Processing Record 13 of Set 12 | outlook
# Processing Record 14 of Set 12 | husavik
# Processing Record 15 of Set 12 | manaus
# Processing Record 16 of Set 12 | bin qirdan
# Processing Record 17 of Set 12 | osa
# Processing Record 18 of Set 12 | subacius
# City not found. Skipping...
# Processing Record 19 of Set 12 | malchin
# Processing Record 20 of Set 12 | pankrushikha
# Processing Record 21 of Set 12 | kajaani
# Processing Record 22 of Set 12 | labuan
# Processing Record 23 of Set 12 | ouallam
# Processing Record 24 of Set 12 | broken hill
# Processing Record 25 of Set 12 | kirando
# Processing Record 26 of Set 12 | cabedelo
# Processing Record 27 of Set 12 | coro
# Processing Record 28 of Set 12 | mahebourg
# Processing Record 29 of Set 12 | awbari
# Processing Record 30 of Set 12 | wanaka
# Processing Record 31 of Set 12 | hobyo
# Processing Record 32 of Set 12 | aginskoye
# Processing Record 33 of Set 12 | waddan
# Processing Record 34 of Set 12 | shahr-e kord
# Processing Record 35 of Set 12 | ossora
# Processing Record 36 of Set 12 | sao joao da barra
# Processing Record 37 of Set 12 | salta
# Processing Record 38 of Set 12 | shimoda
# Processing Record 39 of Set 12 | bonthe
# Processing Record 40 of Set 12 | bossangoa
# Processing Record 41 of Set 12 | amapa
# Processing Record 42 of Set 12 | manoel urbano
# Processing Record 43 of Set 12 | cap estate
# Processing Record 44 of Set 12 | port lincoln
# Processing Record 45 of Set 12 | camacha
# Processing Record 46 of Set 12 | eselnita
# Processing Record 47 of Set 12 | lavrentiya
# Processing Record 48 of Set 12 | brora
# Processing Record 49 of Set 12 | nalut
# Processing Record 50 of Set 12 | el balyana
# City not found. Skipping...
# Processing Record 1 of Set 13 | jutai
# Processing Record 2 of Set 13 | najran
# Processing Record 3 of Set 13 | briancon
# Processing Record 4 of Set 13 | sorsk
# Processing Record 5 of Set 13 | doksy
# Processing Record 6 of Set 13 | biak
# Processing Record 7 of Set 13 | saint-augustin
# Processing Record 8 of Set 13 | tommot
# Processing Record 9 of Set 13 | skowhegan
# Processing Record 10 of Set 13 | san cristobal
# Processing Record 11 of Set 13 | mayumba
# Processing Record 12 of Set 13 | jurado
# Processing Record 13 of Set 13 | dunedin
# Processing Record 14 of Set 13 | tsiroanomandidy
# Processing Record 15 of Set 13 | harper
# Processing Record 16 of Set 13 | moses lake
# Processing Record 17 of Set 13 | quibdo
# Processing Record 18 of Set 13 | luzhou
# Processing Record 19 of Set 13 | kourou
# Processing Record 20 of Set 13 | yangambi
# Processing Record 21 of Set 13 | repino
# Processing Record 22 of Set 13 | batticaloa
# Processing Record 23 of Set 13 | chernyshevskiy
# Processing Record 24 of Set 13 | ovsyanka
# Processing Record 25 of Set 13 | ahipara
# Processing Record 26 of Set 13 | kushima
# Processing Record 27 of Set 13 | soe
# Processing Record 28 of Set 13 | gorontalo
# Processing Record 29 of Set 13 | karpogory
# Processing Record 30 of Set 13 | sao felix do xingu
# Processing Record 31 of Set 13 | claveria
# Processing Record 32 of Set 13 | lloydminster
# Processing Record 33 of Set 13 | alice springs
# Processing Record 34 of Set 13 | tingo maria
# Processing Record 35 of Set 13 | lishui
# Processing Record 36 of Set 13 | mapiri
# Processing Record 37 of Set 13 | maraa
# Processing Record 38 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 13 | srandakan
# Processing Record 40 of Set 13 | ewa beach
# Processing Record 41 of Set 13 | rio grande
# Processing Record 42 of Set 13 | nabul
# City not found. Skipping...
# Processing Record 43 of Set 13 | hervey bay
# Processing Record 44 of Set 13 | upata
# Processing Record 45 of Set 13 | mbanza-ngungu
# Processing Record 46 of Set 13 | cascais
# Processing Record 47 of Set 13 | loyabad
# City not found. Skipping...
# Processing Record 48 of Set 13 | sakakah
# Processing Record 49 of Set 13 | ler
# Processing Record 50 of Set 13 | qasigiannguit
# Processing Record 1 of Set 14 | kiunga
# Processing Record 2 of Set 14 | crestview
# Processing Record 3 of Set 14 | chiredzi
# Processing Record 4 of Set 14 | kapit
# Processing Record 5 of Set 14 | eydhafushi
# Processing Record 6 of Set 14 | port blair
# Processing Record 7 of Set 14 | lincoln
# Processing Record 8 of Set 14 | kashi
# Processing Record 9 of Set 14 | cockburn town
# Processing Record 10 of Set 14 | bheramara
# Processing Record 11 of Set 14 | sambava
# Processing Record 12 of Set 14 | biskupiec
# Processing Record 13 of Set 14 | tabou
# Processing Record 14 of Set 14 | kachiry
# Processing Record 15 of Set 14 | ust-ilimsk
# Processing Record 16 of Set 14 | alekseyevskoye
# Processing Record 17 of Set 14 | samarai
# Processing Record 18 of Set 14 | beyneu
# Processing Record 19 of Set 14 | darayya
# Processing Record 20 of Set 14 | xining
# Processing Record 21 of Set 14 | xingyi
# Processing Record 22 of Set 14 | balikpapan
# Processing Record 23 of Set 14 | magdagachi
# Processing Record 24 of Set 14 | ambovombe
# Processing Record 25 of Set 14 | carlsbad
# Processing Record 26 of Set 14 | coahuayana
# Processing Record 27 of Set 14 | kirya
# Processing Record 28 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 29 of Set 14 | malabo
# Processing Record 30 of Set 14 | gizo
# Processing Record 31 of Set 14 | marawi
# Processing Record 32 of Set 14 | salalah
# Processing Record 33 of Set 14 | mayo
# Processing Record 34 of Set 14 | san quintin
# Processing Record 35 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 14 | banda aceh
# Processing Record 37 of Set 14 | khani
# Processing Record 38 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 39 of Set 14 | yeniseysk
# Processing Record 40 of Set 14 | sungairaya
# Processing Record 41 of Set 14 | pandan
# Processing Record 42 of Set 14 | bac lieu
# Processing Record 43 of Set 14 | monte cristi
# City not found. Skipping...
# Processing Record 44 of Set 14 | sobolevo
# Processing Record 45 of Set 14 | nishihara
# Processing Record 46 of Set 14 | namibe
# Processing Record 47 of Set 14 | dawei
# Processing Record 48 of Set 14 | port keats
# Processing Record 49 of Set 14 | mogadishu
# Processing Record 50 of Set 14 | kovdor
# Processing Record 1 of Set 15 | fethiye
# Processing Record 2 of Set 15 | kirakira
# Processing Record 3 of Set 15 | port augusta
# Processing Record 4 of Set 15 | horni slavkov
# Processing Record 5 of Set 15 | tiruchchendur
# Processing Record 6 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 7 of Set 15 | ardabil
# Processing Record 8 of Set 15 | egvekinot
# Processing Record 9 of Set 15 | buala
# Processing Record 10 of Set 15 | rajanpur
# Processing Record 11 of Set 15 | arawa
# Processing Record 12 of Set 15 | ternate
# Processing Record 13 of Set 15 | batagay
# Processing Record 14 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 15 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 15 | quatre cocos
# Processing Record 17 of Set 15 | khabary
# Processing Record 18 of Set 15 | touros
# Processing Record 19 of Set 15 | sibolga
# Processing Record 20 of Set 15 | peniche
# Processing Record 21 of Set 15 | kupang
# Processing Record 22 of Set 15 | mata
# Processing Record 23 of Set 15 | yuty
# Processing Record 24 of Set 15 | denpasar
# Processing Record 25 of Set 15 | riyadh
# Processing Record 26 of Set 15 | benguela
# Processing Record 27 of Set 15 | talnakh
# Processing Record 28 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 15 | vanavara
# Processing Record 30 of Set 15 | araouane
# Processing Record 31 of Set 15 | baculin
# Processing Record 32 of Set 15 | san pedro
# Processing Record 33 of Set 15 | waingapu
# Processing Record 34 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 35 of Set 15 | kamenka
# Processing Record 36 of Set 15 | praxedis guerrero
# Processing Record 37 of Set 15 | cayenne
# Processing Record 38 of Set 15 | marang
# Processing Record 39 of Set 15 | lac du bonnet
# Processing Record 40 of Set 15 | kankon
# Processing Record 41 of Set 15 | chukhloma
# Processing Record 42 of Set 15 | horsham
# Processing Record 43 of Set 15 | victor harbor
# Processing Record 44 of Set 15 | motygino
# Processing Record 45 of Set 15 | belmonte
# Processing Record 46 of Set 15 | bunia
# Processing Record 47 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 15 | council bluffs
# Processing Record 49 of Set 15 | malakal
# Processing Record 50 of Set 15 | calmar
# Processing Record 1 of Set 16 | grindavik
# Processing Record 2 of Set 16 | fort nelson
# Processing Record 3 of Set 16 | birjand
# Processing Record 4 of Set 16 | batman
# Processing Record 5 of Set 16 | alcudia
# Processing Record 6 of Set 16 | etchojoa
# Processing Record 7 of Set 16 | diamantino
# Processing Record 8 of Set 16 | suntar
# Processing Record 9 of Set 16 | tromso
# Processing Record 10 of Set 16 | rochegda
# Processing Record 11 of Set 16 | weligama
# Processing Record 12 of Set 16 | meadow lake
# Processing Record 13 of Set 16 | cravinhos
# Processing Record 14 of Set 16 | soure
# Processing Record 15 of Set 16 | grand gaube
# Processing Record 16 of Set 16 | itoman
# Processing Record 17 of Set 16 | mahadday weyne
# City not found. Skipping...
# Processing Record 18 of Set 16 | vilyuysk
# Processing Record 19 of Set 16 | serra
# Processing Record 20 of Set 16 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 16 | tabuk
# Processing Record 22 of Set 16 | teya
# Processing Record 23 of Set 16 | slatina
# Processing Record 24 of Set 16 | jinchang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port Alfred      ZA -33.5906   26.8910     59.00        80           0
# 1         Neiafu      TO -18.6500 -173.9833     79.48        69          75
# 2           Hilo      US  19.7297 -155.0900     85.28        79          75
# 3    Pangnirtung      CA  66.1451  -65.7125      9.52        90          21
# 4       Ambilobe      MG -13.2000   49.0500     65.50        91           0
# 5         Avarua      CK -21.2078 -159.7750     78.85        69          75
# 6       Hermanus      ZA -34.4187   19.2345     51.80        80           0
# 7         Biggar      GB  55.6167   -3.5167     45.55        91          41
# 8  Half Moon Bay      US  37.4636 -122.4286     71.80        80          20
# 9           Naze      JP  28.3667  129.4833     67.12        78         100
#
#    Wind Speed Current Description
# 0        4.34           clear sky
# 1        5.75       broken clouds
# 2       13.80       broken clouds
# 3        7.20          few clouds
# 4        3.71           clear sky
# 5       10.36       broken clouds
# 6        8.86           clear sky
# 7        3.09    scattered clouds
# 8       21.85          few clouds
# 9       17.87          light rain

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
